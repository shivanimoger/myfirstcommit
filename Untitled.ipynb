# %%
#day4

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'a':['a0','a1','a2','a3'],'b':['b0','b1','b2','b3'],'c':['c0','c1','c2','c3'],'d':['d0','d1','d2','d3']})

# %%
df2=pd.DataFrame({'a':['a4','a5','a6','a7'],'b':['b4','b5','b6','b7'],'c':['c4','c5','c6','c7'],'d':['d4','d5','d6','d7']})

# %%
df3=pd.DataFrame({'a':['a8','a9','a10','a11'],'b':['b8','b9','b10','b11'],'c':['c8','c9','c10','c11'],'d':['d8','d9','d10','d11']})

# %%
pd.concat([df1,df2,df3])
# Out:
#      a    b    c    d
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#     a   b   c   d   a   b   c   d    a    b    c    d
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
left=pd.DataFrame({'key':['k0','k1','k2','k3'],'a':['a0','a1','a2','a3'],'b':['b0','b1','b2','b3']})

# %%
right=pd.DataFrame({'key':['k0','k1','k2','k3'],'c':['c0','c1','c2','c3'],'d':['d0','d1','d2','d3']})

# %%
#inner join
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   a   b   c   d
# 0  k0  a0  b0  c0  d0
# 1  k1  a1  b1  c1  d1
# 2  k2  a2  b2  c2  d2
# 3  k3  a3  b3  c3  d3

# %%
left=pd.DataFrame({'key1':['k0','k0','k1','k2'],'key2':['k0','k1','k0','k1'],'a':['a0','a1','a2','a3'],'b':['b0','b1','b2','b3']})

# %%
right=pd.DataFrame({'key1':['k0','k1','k1','k2'],'key2':['k0','k0','k0','k0'],'c':['c0','c1','c2','c3'],'d':['d0','d1','d2','d3']})

# %%
#multiple entry
pd.merge(left,right,on=['key1','key2'])
# Out:
#   key1 key2   a   b   c   d
# 0   k0   k0  a0  b0  c0  d0
# 1   k1   k0  a2  b2  c1  d1
# 2   k1   k0  a2  b2  c2  d2

# %%
#outer join everything except intersection
#full join is everything-union
#this is outer join
pd.merge(left,right,how='outer',on=['key1','key2'])
# Out:
#   key1 key2    a    b    c    d
# 0   k0   k0   a0   b0   c0   d0
# 1   k0   k1   a1   b1  NaN  NaN
# 2   k1   k0   a2   b2   c1   d1
# 3   k1   k0   a2   b2   c2   d2
# 4   k2   k1   a3   b3  NaN  NaN
# 5   k2   k0  NaN  NaN   c3   d3

# %%
#right joing
pd.merge(left,right,how='right',on=['key1','key2'])
# Out:
#   key1 key2    a    b   c   d
# 0   k0   k0   a0   b0  c0  d0
# 1   k1   k0   a2   b2  c1  d1
# 2   k1   k0   a2   b2  c2  d2
# 3   k2   k0  NaN  NaN  c3  d3

# %%
#left join
pd.merge(left,right,how='left',on=['key1','key2'])
# Out:
#   key1 key2   a   b    c    d
# 0   k0   k0  a0  b0   c0   d0
# 1   k0   k1  a1  b1  NaN  NaN
# 2   k1   k0  a2  b2   c1   d1
# 3   k1   k0  a2  b2   c2   d2
# 4   k2   k1  a3  b3  NaN  NaN

# %%
left=pd.DataFrame({'a':['a0','a1','a2'],'b':['b0','b1','b2']},index=['k0','k1','k2'])

# %%
right=pd.DataFrame({'c':['c0','c2','c3'],'d':['d0','d2','d3']},index=['k0','k2','k3'])

# %%
#
left.join(right)
# Out:
#      a   b    c    d
# k0  a0  b0   c0   d0
# k1  a1  b1  NaN  NaN
# k2  a2  b2   c2   d2

# %%
left.join(right,how='outer')
# Out:
#       a    b    c    d
# k0   a0   b0   c0   d0
# k1   a1   b1  NaN  NaN
# k2   a2   b2   c2   d2
# k3  NaN  NaN   c3   d3

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# ...

# %%
df.groupby('BasePay')

# %%
by_salary=df.groupby('BasePay')

# %%
df.groupby('BasePay').mean()
# Out:
#                        Id   OvertimePay      OtherPay      Benefits  \
# BasePay
# -166.01      72833.000000    249.020000      0.000000      6.560000
# -121.63      72866.000000    182.700000      0.000000      5.440000
# -109.22      72873.000000    163.830000      0.000000      4.320000
# -106.60      72875.000000    159.900000      0.000000      4.660000
# -101.88      72879.000000    153.080000      0.000000      4.550000
# -93.14       72885.000000    139.970000      0.000000      4.170000
# -87.38       72889.000000    131.060000      0.000000      3.890000
# -75.67       72895.000000    113.760000      0.000000      3.390000
# -59.59       72909.000000     89.650000      0.000000      2.680000
# -30.58       72921.000000     45.870000      0.000000      1.360000
# -9.50        72923.000000     14.250000      0.000000      0.420000
#  0.00        82843.394453    169.263066   4496.862589   1223.155851
#  6.04       148620.000000      0.000000     10.050000      2.300000
# ...

# %%
df[''].value_counts().head(5)
# Out:
# 0.0        1298
# 54703.0     338
# 55026.0     297
# 48472.4     210
# 65448.0     153
# Name: BasePay, dtype: int64

# %%
df[df["EmployeeName"]=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
df[df["EmployeeName"]=='JOSEPH DRISCOLL']['TotalPay']
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %%
df[df["TotalPay"]==df['TotalPay'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
df[df["TotalPay"]==df['TotalPay'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
by_year=df.groupby('Year')

# %%
df.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(df['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
df['title_len']=df['JobTitle'].apply(len)

# %%
#very small values=no correlation
df[['title_len','TotalPay']].corr()
# Out:
#            title_len  TotalPay
# title_len   1.000000 -0.015356
# TotalPay   -0.015356  1.000000

# %%
import numpy as np

# %%
a=np.array([[1,2,3],[4,5,6],[7,8,8]])

# %%
from scipy import linalg

# %%
linalg.det(a)
# Out:
# 2.999999999999997

# %%
#LU decomposition matrix
P,L,U=linalg.lu(a)

# %%
P#permutation
# Out:
# array([[0., 1., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.]])

# %%
L#lower
# Out:
# array([[1.        , 0.        , 0.        ],
#        [0.14285714, 1.        , 0.        ],
#        [0.57142857, 0.5       , 1.        ]])

# %%
U#upper
# Out:
# array([[7.        , 8.        , 8.        ],
#        [0.        , 0.85714286, 1.85714286],
#        [0.        , 0.        , 0.5       ]])

# %%
np.dot(L,U)
# Out:
# array([[7., 8., 8.],
#        [1., 2., 3.],
#        [4., 5., 6.]])

# %%
#eigan values ,Vectors
EW,EV=linalg.eig(a)

# %%
EW
# Out:
# array([15.55528261+0.j, -1.41940876+0.j, -0.13587385+0.j])

# %%
EV
# Out:
# array([[-0.24043423, -0.67468642,  0.51853459],
#        [-0.54694322, -0.23391616, -0.78895962],
#        [-0.80190056,  0.70005819,  0.32964312]])

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1',index_col=0)
df2=pd.read_csv('df2')

# %%
#histogram

# %%
df1['A'].hist()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %%
plt.style.use('bmh')
df1['A'].hist()

# %%
plt.style.use('dark_background')
df1['A'].hist()

# %%
#area

# %%
df2.plot.area(alpha=0.4)
#aspect ratio alpha0.4

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df3
# Out:
#      a    b    c    d
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# 2000-01-06 -0.891165  0.741147  0.237482 -1.501909
# 2000-01-07  1.111132  0.287674  0.183012  1.359046
# 2000-01-08 -1.290901 -0.549247 -0.825183  0.328940
# 2000-01-09 -1.689655  0.818016  1.137704  0.334530
# 2000-01-10  0.416580 -1.188162  0.753229 -0.728224
# 2000-01-11  0.328968 -1.087598  1.352827  0.997733
# 2000-01-12  0.263585 -0.187620 -1.083475 -0.099250
# 2000-01-13 -0.293007 -0.813710  2.726993  1.869973
# 2000-01-14  1.108678 -0.339782  1.923170  0.156140
# 2000-01-15  1.818886  0.979137  0.554317  0.564793
# 2000-01-16  1.027913  0.419564  0.684419 -2.063248
# 2000-01-17 -0.016772  0.078902 -0.271826  1.955717
# ...

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-ce40ab214708> in <module>()
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3003             >>> lines = df.plot.line(x='pig', y='horse')
#    3004         """
# -> 3005         return self(kind='line', x=x, y=y, **kwds)
#    3006
#    3007     def bar(self, x=None, y=None, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...
